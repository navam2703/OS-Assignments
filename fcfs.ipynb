# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd
df = pd.read_csv("data/fcfsdata.csv")

# %%
df = df.set_index("n1=n2=n3")
df.head()
# Out:
#           c1wait    c2wait     c3wait    c1turn     c2turn     c3turn
# n1=n2=n3
# 100000     3.825  1914.790   3727.679  1914.789   3727.677   5084.620
# 200000     2.236  4160.626   8028.956  4160.625   8028.956  11021.315
# 300000     3.391  6287.028  11216.186  6287.028  11216.185  15942.569
# 400000     4.174  6758.626  13165.892  6758.625  13165.892  19142.027
# 500000     3.974  8309.396  17106.276  8309.395  17106.275  26171.897

# %%
df.rename(columns = {'c1wait': 'C1 Waiting Time', 'c2wait': 'C2 Waiting Time', 'c3wait': 'C3 Waiting Time'
                    , 'c1turn': 'C1 Turnaround Time', 'c2turn': 'C2 Turnaround Time', 'c3turn': 'C3 Turnaround Time'}, inplace = True)
df
# Out:
#           C1 Waiting Time  C2 Waiting Time  C3 Waiting Time  \
# n1=n2=n3
# 100000              3.825         1914.790         3727.679
# 200000              2.236         4160.626         8028.956
# 300000              3.391         6287.028        11216.186
# 400000              4.174         6758.626        13165.892
# 500000              3.974         8309.396        17106.276
# 600000              3.952        10379.071        21415.420
# 700000              1.951        12368.528        25986.495
# 800000              4.193        12973.613        28924.724
# 900000              2.923        18193.597        39902.430
# 1000000             3.892        21156.761        46369.408
#
#           C1 Turnaround Time  C2 Turnaround Time  C3 Turnaround Time
# n1=n2=n3
# 100000              1914.789            3727.677            5084.620
# 200000              4160.625            8028.956           11021.315
# 300000              6287.028           11216.185           15942.569
# 400000              6758.625           13165.892           19142.027
# 500000              8309.395           17106.275           26171.897
# 600000             10379.070           21415.419           33616.583
# 700000             12368.527           25986.494           40894.465
# 800000             12973.612           28924.723           46461.667
# 900000             18193.597           39902.429           59474.819
# 1000000            21156.760           46369.407           66661.730

# %%
df1 = df[['C1 Waiting Time','C1 Turnaround Time']]
plt.figure()
df1.plot(title='Waiting and Turnaround time for process C1')
plt.xlabel('Workload Size')
plt.ylabel('Time taken in ms')
plt.show()

# %%
df2 = df[['C2 Waiting Time','C2 Turnaround Time']]
plt.figure()
df2.plot(title='Waiting and Turnaround time for process C2')
plt.xlabel('Workload Size')
plt.ylabel('Time taken in ms')
plt.show()

# %%
df3 = df[['C3 Waiting Time','C3 Turnaround Time']]
plt.figure()
df3.plot(title='Waiting and Turnaround time for process C3')
plt.xlabel('Workload Size')
plt.ylabel('Time taken in ms')
plt.show()

# %%
plt.figure()
df.plot(title='Waiting and Turnaround time')
plt.xlabel('Workload Size')
plt.ylabel('Time taken in ms')
plt.show()
