# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/rrdata3.csv")
df = df.set_index("n1=n2=n3")
df.rename(columns = {'c1wait': 'C1 Waiting Time', 'c2wait': 'C2 Waiting Time', 'c3wait': 'C3 Waiting Time'
                    , 'c1turn': 'C1 Turnaround Time', 'c2turn': 'C2 Turnaround Time', 'c3turn': 'C3 Turnaround Time'}, inplace = True)
df.head()
# Out:
#           C1 Waiting Time  C2 Waiting Time  C3 Waiting Time  \
# n1=n2=n3
# 100000                  0                3                6
# 200000                  6                9                6
# 300000                  6                9               12
# 400000                 12               15               18
# 500000                 18               21               24
#
#           C1 Turnaround Time  C2 Turnaround Time  C3 Turnaround Time
# n1=n2=n3
# 100000                     3                   6                   9
# 200000                    12                  15                   9
# 300000                    12                  15                  18
# 400000                    21                  24                  27
# 500000                    30                  33                  36

# %%
df1 = df[['C1 Waiting Time','C1 Turnaround Time']]
plt.figure()
df1.plot(title='Waiting and Turnaround time for process C1 for time quantum = 3 sec')
plt.xlabel('Workload Size')
plt.ylabel('Time taken in s')
plt.show()

# %%
df2 = df[['C2 Waiting Time','C2 Turnaround Time']]
plt.figure()
df2.plot(title='Waiting and Turnaround time for process C2 for time quantum = 3 sec')
plt.xlabel('Workload Size')
plt.ylabel('Time taken in s')
plt.show()

# %%
df3 = df[['C3 Waiting Time','C3 Turnaround Time']]
plt.figure()
df3.plot(title='Waiting and Turnaround time for process C3 for time quantum = 3 sec')
plt.xlabel('Workload Size')
plt.ylabel('Time taken in s')
plt.show()

# %%
plt.figure()
df.plot(title='Waiting and Turnaround time for time quantum = 3 sec')
plt.xlabel('Workload Size')
plt.ylabel('Time taken in s')
plt.show()
